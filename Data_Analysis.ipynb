# %%
import pandas as pd
import dask.dataframe as dd
#import dask
pd.options.display.max_columns = None

# %%
path = 's3://hackathon-bbva-parceros/t_mdco_tfra400_Base3M_1.0.csv'
print(path)
# Out:
# s3://hackathon-bbva-parceros/t_mdco_tfra400_Base3M_1.0.csv

# %%
# %%time
df = pd.read_csv(path, dtype={"producto_1_number":str, "bin_2_number":str, "NSS":str, "pasaporte":str})
# Out:
# CPU times: user 29.9 s, sys: 4.24 s, total: 34.2 s
# Wall time: 55.2 s

# %%
df
# Out:
#          id_cliente    NU_CTE CANAL_ENTRADA  clave_id       desc_text  \
# 0                 1  B3477219          BNET    640402  iolandesnaddon
# 1                 2  W0818632        BMOVIL    820713   jemiepeachman
# 2                 3  Z4396398          BNET    580905    justusmurton
# 3                 4  L1839991          BNET    530805   foresternanni
# 4                 5  Z4139418          BNET    800731  nathaliachiles
# ...             ...       ...           ...       ...             ...
# 2999995     2999996  Q9338732        BMOVIL    430531     zaradresser
# 2999996     2999997  I2146781        BMOVIL    831211   skippermander
# 2999997     2999998  A2205051        BMOVIL    880903    deboramounce
# 2999998     2999999  W4868807        BMOVIL    950101     alanahholde
# 2999999     3000000  S1808601        BMOVIL    581015      yurihovert
#
#         producto_id           correo_id  CVV_secreto   CURP CODIGO_BANCO  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 32 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   id_cliente             int64
#  1   NU_CTE                 object
#  2   CANAL_ENTRADA          object
#  3   clave_id               int64
#  4   desc_text              object
#  5   producto_id            object
#  6   correo_id              object
#  7   CVV_secreto            int64
#  8   CURP                   object
#  9   CODIGO_BANCO           object
#  10  REFERENCIA_PAGO        object
#  11  clave_secundaria_text  object
#  12  desc_id                object
#  13  clave_primaria_text    object
#  14  producto_1_number      object
#  15  tel_id                 object
#  16  bin_2_number           object
#  17  SUBCANAL_ENTRANTE      int64
#  18  CODIGO_ENTIDAD_ORI     int64
#  19  nombre_text            object
#  20  apellid@_text          object
#  21  INSTRUMENTO_PAGO       object
# ...

# %%
df.columns
# Out:
# Index(['id_cliente', 'NU_CTE', 'CANAL_ENTRADA', 'clave_id', 'desc_text',
#        'producto_id', 'correo_id', 'CVV_secreto', 'CURP', 'CODIGO_BANCO',
#        'REFERENCIA_PAGO', 'clave_secundaria_text', 'desc_id',
#        'clave_primaria_text', 'producto_1_number', 'tel_id', 'bin_2_number',
#        'SUBCANAL_ENTRANTE', 'CODIGO_ENTIDAD_ORI', 'nombre_text',
#        'apellid@_text', 'INSTRUMENTO_PAGO', 'pasaporte', 'TERMINAL',
#        'FECHA_ULTIMO_USO', 'NSS', 'REFERENCIA_NUMERICA', 'MOTIVO_PAGO',
#        'INFE_id', 'registro.xls', 'TIPO_TARJETA', 'agrupacion_id'],
#       dtype='object')

# %%
df[['pasaporte','NSS']].sample(10)
# Out:
#                pasaporte            NSS
# 1424438              NaN   573130564165
# 1437475   8AD1C9A41489D4  1013005406640
# 141499               NaN   437314006640
# 1609029              NaN   745772700252
# 1921456   CA02F2D2843175   102334567214
# 2874378  10375EDE34CB98E   336064003100
# 366112    FF34C281DE66C0   626207246041
# 1467443   DFA4F2E7ADBC2D  1044112247440
# 500076   1001F26BFE1D2CC   432235230103
# 2769799              NaN    17017405627

# %%
df[['correo_id','desc_text','nombre_text','FECHA_ULTIMO_USO']]
# Out:
#                   correo_id       desc_text   nombre_text FECHA_ULTIMO_USO
# 0               tnioPmirG91  iolandesnaddon     isnaddon0       1972-07-10
# 1             enaLedisyaB18   jemiepeachman    jpeachman1       1998-08-22
# 2            kraPrelliM2518    justusmurton      jmurton2       1991-10-28
# 3            teertSshcaS171   foresternanni       fnanni3       1979-09-03
# 4         lliHtserclezaH854  nathaliachiles      nchiles4       1996-09-13
# ...                     ...             ...           ...              ...
# 2999995     evirDdoowtnerB5     zaradresser  zdresser255n       1966-10-19
# 2999996   teertSairotciV015   skippermander   smander255o       1961-01-29
# 2999997  noitcnuJdnalecarG7    deboramounce   dmounce255p       1993-08-06
# 2999998    retneCrereihT816     alanahholde    aholde255q       1964-03-16
# 2999999        ecalPneerG55      yurihovert   yhovert255r       1959-09-17
#
# [3000000 rows x 4 columns]

# %%
df.loc[:,'correo_id'].apply(lambda x: x[::-1])
# Out:
# 0                 19GrimPoint
# 1               81BaysideLane
# 2              8152MillerPark
# 3              171SachsStreet
# 4           458HazelcrestHill
#                   ...
# 2999995       5BrentwoodDrive
# 2999996     510VictoriaStreet
# 2999997    7GracelandJunction
# 2999998      618ThiererCenter
# 2999999          55GreenPlace
# Name: correo_id, Length: 3000000, dtype: object

# %%
df.columns
# Out:
# Index(['id_cliente', 'NU_CTE', 'CANAL_ENTRADA', 'clave_id', 'desc_text',
#        'producto_id', 'correo_id', 'CVV_secreto', 'CURP', 'CODIGO_BANCO',
#        'REFERENCIA_PAGO', 'clave_secundaria_text', 'desc_id',
#        'clave_primaria_text', 'producto_1_number', 'tel_id', 'bin_2_number',
#        'SUBCANAL_ENTRANTE', 'CODIGO_ENTIDAD_ORI', 'nombre_text',
#        'apellid@_text', 'INSTRUMENTO_PAGO', 'pasaporte', 'TERMINAL',
#        'FECHA_ULTIMO_USO', 'NSS', 'REFERENCIA_NUMERICA', 'MOTIVO_PAGO',
#        'INFE_id', 'registro.xls', 'TIPO_TARJETA', 'agrupacion_id'],
#       dtype='object')

# %%
df.loc[:,'NSS'].apply(lambda x: str(int(x, 8))).apply(len).value_counts()
# Out:
# 11    2700259
# 10     269826
# 9       27028
# 8        2603
# 7         255
# 6          28
# 5           1
# Name: NSS, dtype: int64

# %%
def build_name(row, **_):
    name = row['desc_text']
    lastShort = row['desc_id'][2:]
    index = name.find(lastShort.lower())
    return f'{name[:index].capitalize()} {name[index:].capitalize()}'

# %%
def get_name(ini, target):
    f = ini[:2]
    l = ini[2:]
    names = target.split(l.lower())
    if(len(names) < 2 or target.find(f.lower()) != 0):
        return ""
    ff = len(names[0])
    return f + target[2:ff] + " " + l + target[ff + len(l):]

# %%
# %%time
names = []
initials = df['desc_id'].tolist()
targets = df['desc_text'].tolist()
for i in range(len(initials)):
    ini = initials[i]
    target = targets[i]
    ans = get_name(ini, target)
    names.append(ans)
# Out:
# CPU times: user 5.83 s, sys: 85.3 ms, total: 5.92 s
# Wall time: 5.92 s

# %%
print(names[:100])
# Out:
# ['Iolande Snaddon', 'Jemie Peachman', 'Justus Murton', 'Forester Nanni', 'Nathalia Chiles', 'Cal Ellson', 'Domenic Limpenny', 'Mallorie Edgerley', 'Kally Jeavons', 'Ricki Oret', 'Mina Sleeman', 'Shamus Delacote', 'Verne Duligall', 'Cherish Trevaskus', 'Alvy Whinray', 'Pepe Naulty', 'Alyss Buss', 'Milzie Sellack', 'Dannye Rusted', 'Geneva Fitzgibbon', 'Abbe Danilishin', 'Alexi Elwin', 'Luigi Breakey', 'Bron Beslier', 'Purcell Lowcock', 'Clyde Vouls', 'Zena Baseke', 'Cthrine Tristram', 'Gayler Brister', 'Ermentrude Allitt', 'Jessie Brogioni', "Lorne O'donohue", 'Winny Welham', 'Alden Civitillo', 'Bridgette Doubleday', 'Kizzee Phlipon', 'Cherise Dugall', 'Catlin Stackbridge', 'Katri Neneale', 'Pen Fishenden', 'Dorisa Arkil', 'Jocelyne Wilcocks', 'Liz Fronks', 'Phip Gronauer', "Gerda O'reagan", 'Corabella Leary', 'Irena Longcaster', 'Nickey Danilyuk', 'Marissa Cappleman', 'Tomasina Phette', 'Tiler Haughton', 'Philippine Hosier', 'Edee Balling', 'Arne Macgillreich', 'Winn Hannant', 'Adeli
# ...

# %%
# !head -n 2 t_mdco_tfra400_Base3M_1.0.csv
# !ls
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-7fcfac939e55> in <module>
# ----> 1 get_ipython().system('head -n 2 t_mdco_tfra400_Base3M_1.0.csv')
#       2 get_ipython().system('ls')
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2454         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2455         # Instead, we store the exit_code in user_ns.
# -> 2456         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2457
#    2458     def system_raw(self, cmd):
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     154                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     155             else:
# ...

# %%
df.CODIGO_ENTIDAD_ORI.unique()
# Out:
# array([74])

# %%
for col in df.columns:
    print(col,df[col].astype(str).map(len).unique())

    print('-------')
# Out:
# id_cliente [1 2 3 4 5 6 7]
# -------
# NU_CTE [8]
# -------
# CANAL_ENTRADA [4 6]
# -------
# clave_id [6 3 4]
# -------
# desc_text [14 13 12  9 15 16 11 10 18 17  8 19 20 23  7 21  6 25  5 22 26 24 27 28
#  29 30  4]
# -------
# producto_id [3]
# -------
# correo_id [11 13 14 17 16 12 21 15 23 19 10 20 18 22  9  8 26 25 24 27  7 28]
# -------
# CVV_secreto [3 2 1]
# -------
# CURP [5]
# -------
# CODIGO_BANCO [4]
# -------
# REFERENCIA_PAGO [20]
# -------
# clave_secundaria_text [16 17 15 12]
# -------
# desc_id [4 3]
# -------
# clave_primaria_text [15 16 14 11  3]
# -------
# producto_1_number [10  3]
# -------
# tel_id [12]
# -------
# bin_2_number [10  9  3]
# -------
# SUBCANAL_ENTRANTE [1]
# -------
# CODIGO_ENTIDAD_ORI [2]
# -------
# nombre_text [ 9 10  8  7  6 11 12  3 14  4 13 15  5 17 16 18 21 20 19 22]
# -------
# apellid@_text [ 9 10  6  5  8 14 19 11 16 17  4  7 12 13  3 15 22 20 18]
# -------
# INSTRUMENTO_PAGO [10]
# -------
# pasaporte [15  3 14 13 12 11 10]
# ...

# %%
df
# Out:
#          id_cliente    NU_CTE CANAL_ENTRADA  clave_id       desc_text  \
# 0                 1  B3477219          BNET    640402  iolandesnaddon
# 1                 2  W0818632        BMOVIL    820713   jemiepeachman
# 2                 3  Z4396398          BNET    580905    justusmurton
# 3                 4  L1839991          BNET    530805   foresternanni
# 4                 5  Z4139418          BNET    800731  nathaliachiles
# ...             ...       ...           ...       ...             ...
# 2999995     2999996  Q9338732        BMOVIL    430531     zaradresser
# 2999996     2999997  I2146781        BMOVIL    831211   skippermander
# 2999997     2999998  A2205051        BMOVIL    880903    deboramounce
# 2999998     2999999  W4868807        BMOVIL    950101     alanahholde
# 2999999     3000000  S1808601        BMOVIL    581015      yurihovert
#
#         producto_id           correo_id  CVV_secreto   CURP CODIGO_BANCO  \
# ...

# %%
df.loc[:,'pasaporte'].dropna().apply(lambda x: str(int(x, 16))).apply(len).value_counts()
# Out:
# 17    1973057
# 16     197749
# 15      19846
# 14       1962
# 13        180
# 12         18
# 11          1
# Name: pasaporte, dtype: int64

# %%
df.loc[:,'pasaporte'].dropna().apply(lambda x: str(int(x, 16)))
# Out:
# 0          96686099162290543
# 2          35250537203699050
# 4           6542376803149778
# 5          71783326331098657
# 7          54324583194209803
#                  ...
# 2999993    48378223475542246
# 2999995    72916483490239047
# 2999996    20435652049221291
# 2999998    43855354376114202
# 2999999    89026804955573024
# Name: pasaporte, Length: 2192813, dtype: object

# %%
df.loc[:,'producto_1_number'].dropna().apply(lambda x: str(int(x, 2)))
# Out:
# 0          534
# 1          534
# 2          541
# 3          963
# 4          531
#           ...
# 2999995    932
# 2999996    932
# 2999997    889
# 2999998    889
# 2999999    531
# Name: producto_1_number, Length: 2699495, dtype: object

# %%
df.loc[:,'bin_2_number'].dropna().apply(lambda x: str(int(x, 2)))
# Out:
# 0          261
# 1          340
# 2          645
# 3          105
# 4          309
#           ...
# 2999995     30
# 2999996    108
# 2999997    377
# 2999998    377
# 2999999    309
# Name: bin_2_number, Length: 2699495, dtype: object

# %%
# !ls
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-32-7cb81ad7c064> in <module>
# ----> 1 get_ipython().system('ls')
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2454         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2455         # Instead, we store the exit_code in user_ns.
# -> 2456         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2457
#    2458     def system_raw(self, cmd):
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     154                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     155             else:
# --> 156                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
# ...
